# %%
# !pip install datasets transformers evaluate
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (3.2.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.44.2)
# Requirement already satisfied: evaluate in /usr/local/lib/python3.10/dist-packages (0.4.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.16.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.1.4)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.5)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets) (2024.6.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.10.5)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.24.7)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.9.11)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.11.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.0->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)

# %%
import pandas as pd

# Loading CSV file, handling unterminated strings
data = pd.read_csv('/content/questionsdf.csv', quoting=3, on_bad_lines='skip')

# Preview the dataset
print(data.head())
# Out:
#                               Entity  \
# 0  Non-alcoholic Fatty Liver Disease
# 1  Non-alcoholic Fatty Liver Disease
# 2  Non-alcoholic Fatty Liver Disease
# 3  Non-alcoholic Fatty Liver Disease
# 4  Non-alcoholic Fatty Liver Disease
#
#                                             Question  \
# 0         What is Non-alcoholic Fatty Liver Disease?
# 1         Explain Non-alcoholic Fatty Liver Disease.
# 2  What does Non-alcoholic Fatty Liver Disease mean?
# 3  Can you explain Non-alcoholic Fatty Liver Dise...
# 4  Give a definition for Non-alcoholic Fatty Live...
#
#                                               Answer
# 0  A term referring to fatty replacement of the h...
# 1  A term referring to fatty replacement of the h...
# 2  A term referring to fatty replacement of the h...
# 3  A term referring to fatty replacement of the h...
# 4  A term referring to fatty replacement of the h...

# %%
from datasets import Dataset

# Convert the dataframe into Hugging Face Dataset
qa_dataset = Dataset.from_pandas(data)

# Preview dataset
print(qa_dataset)
# Out:
# Dataset({
#     features: ['Entity', 'Question', 'Answer'],
#     num_rows: 84320
# })

# %%
from sklearn.model_selection import train_test_split

# Split into training and testing
train_data, test_data = train_test_split(data, test_size=0.2, random_state=42)

# Convert to Hugging Face datasets
train_dataset = Dataset.from_pandas(train_data)
test_dataset = Dataset.from_pandas(test_data)

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

# Load tokenizer and model
model_name = "t5-small"  # Change to your desired model
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)

# %%
def preprocess_function(example):
    inputs = tokenizer(
        example["Question"], max_length=512, truncation=True, padding="max_length"
    )
    outputs = tokenizer(
        example["Answer"], max_length=512, truncation=True, padding="max_length"
    )
    inputs["labels"] = outputs["input_ids"]
    return inputs

# Apply preprocessing
train_tokenized = train_dataset.map(preprocess_function, batched=True)
test_tokenized = test_dataset.map(preprocess_function, batched=True)
# Out:
# Map:   0%|          | 0/67456 [00:00<?, ? examples/s]
# Map:   0%|          | 0/16864 [00:00<?, ? examples/s]

# %%
from transformers import Seq2SeqTrainingArguments

training_args = Seq2SeqTrainingArguments(
    output_dir="./results",
    evaluation_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=4,
    per_device_eval_batch_size=4,
    weight_decay=0.01,
    save_total_limit=2,
    num_train_epochs=3,
    predict_with_generate=True,
    logging_dir="./logs",
)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(

# %%
from transformers import Seq2SeqTrainer

trainer = Seq2SeqTrainer(
    model=model,
    args=training_args,
    train_dataset=train_tokenized,
    eval_dataset=test_tokenized,
    tokenizer=tokenizer,
)

# Train the model
trainer.train()
# Out:
#     <div>
#
#       <progress value='36218' max='50592' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [36218/50592 2:07:14 < 50:30, 4.74 it/s, Epoch 2.15/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.072600</td>
#       <td>0.055206</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.051600</td>
#       <td>0.039331</td>
#     </tr>
#   </tbody>
# </table><p>
# Buffered data was truncated after reaching the output size limit.

# %%
from transformers import AutoModelForSeq2SeqLM

latest_checkpoint = "./results/checkpoint-41500"  # Path to the latest checkpoint
model = AutoModelForSeq2SeqLM.from_pretrained(latest_checkpoint)

# %%
from transformers import Seq2SeqTrainingArguments

training_args = Seq2SeqTrainingArguments(
    output_dir="./results",  # Same as before
    per_device_train_batch_size=16,  # Adjust if needed
    num_train_epochs=3,  # Total number of epochs (not the remaining epochs)
    learning_rate=5e-5,  # Same learning rate
    evaluation_strategy="epoch",
    save_strategy="epoch",
    logging_dir="./logs",  # Optional logging directory
    logging_steps=500,
    save_total_limit=2,  # Keep only the last 2 checkpoints
)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(

# %% [markdown]
# ## Here a code chunk is missing where I trained the last epoch using the checkpoint 41500.

# %%
import os

checkpoints = [d for d in os.listdir("./results") if d.startswith("checkpoint")]
checkpoints.sort(key=lambda x: int(x.split('-')[-1]))  # Sort by step number
print("Available checkpoints:", checkpoints)
# Out:
# Available checkpoints: ['checkpoint-41500', 'checkpoint-50592']

# %%
latest_checkpoint = "./results/checkpoint-50592"
print(f"Using latest checkpoint: {latest_checkpoint}")
# Out:
# Using latest checkpoint: ./results/checkpoint-50592

# %%
from transformers import T5ForConditionalGeneration, T5Tokenizer

model = T5ForConditionalGeneration.from_pretrained(latest_checkpoint)
tokenizer = T5Tokenizer.from_pretrained(latest_checkpoint)
# Out:
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565

# %%
from transformers import Seq2SeqTrainer, Seq2SeqTrainingArguments

training_args = Seq2SeqTrainingArguments(
    output_dir="./results",
    per_device_eval_batch_size=16,  # Set batch size for prediction
)

trainer = Seq2SeqTrainer(
    model=model,
    args=training_args,
    tokenizer=tokenizer,
)

# %%
import torch

# Force model and trainer to use CPU
trainer.model.to("cpu")

# Move dataset to CPU
def move_to_cpu(example):
    return {key: torch.tensor(value).to("cpu") if isinstance(value, list) else value for key, value in example.items()}

test_tokenized = test_tokenized.map(move_to_cpu)
# Out:
# Map:   0%|          | 0/16864 [00:00<?, ? examples/s]

# %% [markdown]
# ## I had to move to CPU as GPU memory was full and the sessions were crashing continously

# %%
batch_size = 8
num_batches = len(test_tokenized) // batch_size + int(len(test_tokenized) % batch_size != 0)

predicted_answers = []
true_answers = []

for i in range(num_batches):
    print(f"Processing batch {i+1}/{num_batches}...")
    start_idx = i * batch_size
    end_idx = min(start_idx + batch_size, len(test_tokenized))

    # Select batch
    batch_data = test_tokenized.select(range(start_idx, end_idx))
    input_ids = torch.tensor(batch_data["input_ids"]).to("cpu")
    attention_mask = torch.tensor(batch_data["attention_mask"]).to("cpu")

    # Generate predictions using the model
    with torch.no_grad():
        outputs = trainer.model.generate(input_ids=input_ids, attention_mask=attention_mask)

    # Decode predictions and append
    predicted_answers.extend(tokenizer.batch_decode(outputs, skip_special_tokens=True))
    true_answers.extend(test_dataset["Answer"][start_idx:end_idx])  # Adjust if test_dataset is a DataFrame
# Out:
# Processing batch 1/2108...
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1258: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Processing batch 2/2108...
# Processing batch 3/2108...
# Processing batch 4/2108...
# Processing batch 5/2108...
# Processing batch 6/2108...
# Processing batch 7/2108...
# Processing batch 8/2108...
# Processing batch 9/2108...
# Processing batch 10/2108...
# Processing batch 11/2108...
# Processing batch 12/2108...
# Processing batch 13/2108...
# Processing batch 14/2108...
# Processing batch 15/2108...
# Processing batch 16/2108...
# Processing batch 17/2108...
# Processing batch 18/2108...
# Processing batch 19/2108...
# Processing batch 20/2108...
# Processing batch 21/2108...
# Processing batch 22/2108...
# Processing batch 23/2108...
# Processing batch 24/2108...
# Processing batch 25/2108...
# Processing batch 26/2108...
# Processing batch 27/2108...
# Processing batch 28/2108...
# Processing batch 29/2108...
# Processing batch 30/2108...
# Processing batch 31/2108...
# Processing batch 32/2108...
# Processing batch 33/2108...
# Processing batch 34/2108...
# Processing batch 35/2108...
# Processing batch 36/2108...
# Processing batch 37/2108...
# Processing batch 38/2108...
# Processing batch 39/2108...
# Processing batch 40/2108...
# Processing batch 41/2108...
# Processing batch 42/2108...
# Processing batch 43/2108...
# Processing batch 44/2108...
# Processing batch 45/2108...
# Processing batch 46/2108...
# Processing batch 47/2108...
# Processing batch 48/2108...
# Processing batch 49/2108...
# Processing batch 50/2108...
# Processing batch 51/2108...
# Processing batch 52/2108...
# Processing batch 53/2108...
# Processing batch 54/2108...
# Processing batch 55/2108...
# Processing batch 56/2108...
# Processing batch 57/2108...
# Processing batch 58/2108...
# Processing batch 59/2108...
# Processing batch 60/2108...
# Processing batch 61/2108...
# Processing batch 62/2108...
# Processing batch 63/2108...
# Processing batch 64/2108...
# Processing batch 65/2108...
# Processing batch 66/2108...
# Processing batch 67/2108...
# Processing batch 68/2108...
# Processing batch 69/2108...
# Processing batch 70/2108...
# Processing batch 71/2108...
# Processing batch 72/2108...
# Processing batch 73/2108...
# Processing batch 74/2108...
# Processing batch 75/2108...
# Processing batch 76/2108...
# Processing batch 77/2108...
# Processing batch 78/2108...
# Processing batch 79/2108...
# Processing batch 80/2108...
# Processing batch 81/2108...
# Processing batch 82/2108...
# Processing batch 83/2108...
# Processing batch 84/2108...
# Processing batch 85/2108...
# Processing batch 86/2108...
# Processing batch 87/2108...
# Processing batch 88/2108...
# Processing batch 89/2108...
# Processing batch 90/2108...
# Processing batch 91/2108...
# Processing batch 92/2108...
# Processing batch 93/2108...
# Processing batch 94/2108...
# Processing batch 95/2108...
# Processing batch 96/2108...
# Processing batch 97/2108...
# Processing batch 98/2108...
# Processing batch 99/2108...
# Processing batch 100/2108...
# Processing batch 101/2108...
# Processing batch 102/2108...
# Processing batch 103/2108...
# Processing batch 104/2108...
# Processing batch 105/2108...
# Processing batch 106/2108...
# Processing batch 107/2108...
# Processing batch 108/2108...
# Processing batch 109/2108...
# Processing batch 110/2108...
# Processing batch 111/2108...
# Processing batch 112/2108...
# Processing batch 113/2108...
# Processing batch 114/2108...
# Processing batch 115/2108...
# Processing batch 116/2108...
# Processing batch 117/2108...
# Processing batch 118/2108...
# Processing batch 119/2108...
# Processing batch 120/2108...
# Processing batch 121/2108...
# Processing batch 122/2108...
# Processing batch 123/2108...
# Processing batch 124/2108...
# Processing batch 125/2108...
# Processing batch 126/2108...
# Processing batch 127/2108...
# Processing batch 128/2108...
# Processing batch 129/2108...
# Processing batch 130/2108...
# Processing batch 131/2108...
# Processing batch 132/2108...
# Processing batch 133/2108...
# Processing batch 134/2108...
# Processing batch 135/2108...
# Processing batch 136/2108...
# Processing batch 137/2108...
# Processing batch 138/2108...
# Processing batch 139/2108...
# Processing batch 140/2108...
# Processing batch 141/2108...
# Processing batch 142/2108...
# Processing batch 143/2108...
# Processing batch 144/2108...
# Processing batch 145/2108...
# Processing batch 146/2108...
# Processing batch 147/2108...
# Processing batch 148/2108...
# Processing batch 149/2108...
# Processing batch 150/2108...
# Processing batch 151/2108...
# Processing batch 152/2108...
# Processing batch 153/2108...
# Processing batch 154/2108...
# Processing batch 155/2108...
# Processing batch 156/2108...
# Processing batch 157/2108...
# Processing batch 158/2108...
# Processing batch 159/2108...
# Processing batch 160/2108...
# Processing batch 161/2108...
# Processing batch 162/2108...
# Processing batch 163/2108...
# Processing batch 164/2108...
# Processing batch 165/2108...
# Processing batch 166/2108...
# Processing batch 167/2108...
# Processing batch 168/2108...
# Processing batch 169/2108...
# Processing batch 170/2108...
# Processing batch 171/2108...
# Processing batch 172/2108...
# Processing batch 173/2108...
# Processing batch 174/2108...
# Processing batch 175/2108...
# Processing batch 176/2108...
# Processing batch 177/2108...
# Processing batch 178/2108...
# Processing batch 179/2108...
# Processing batch 180/2108...
# Processing batch 181/2108...
# Processing batch 182/2108...
# Processing batch 183/2108...
# Processing batch 184/2108...
# Processing batch 185/2108...
# Processing batch 186/2108...
# Processing batch 187/2108...
# Processing batch 188/2108...
# Processing batch 189/2108...
# Processing batch 190/2108...
# Processing batch 191/2108...
# Processing batch 192/2108...
# Processing batch 193/2108...
# Processing batch 194/2108...
# Processing batch 195/2108...
# Processing batch 196/2108...
# Processing batch 197/2108...
# Processing batch 198/2108...
# Processing batch 199/2108...
# Processing batch 200/2108...
# Processing batch 201/2108...
# Processing batch 202/2108...
# Processing batch 203/2108...
# Processing batch 204/2108...
# Processing batch 205/2108...
# Processing batch 206/2108...
# Processing batch 207/2108...
# Processing batch 208/2108...
# Processing batch 209/2108...
# Processing batch 210/2108...
# Processing batch 211/2108...
# Processing batch 212/2108...
# Processing batch 213/2108...
# Processing batch 214/2108...
# Processing batch 215/2108...
# Processing batch 216/2108...
# Processing batch 217/2108...
# Processing batch 218/2108...
# Processing batch 219/2108...
# Processing batch 220/2108...
# Processing batch 221/2108...
# Processing batch 222/2108...
# Processing batch 223/2108...
# Processing batch 224/2108...
# Processing batch 225/2108...
# Processing batch 226/2108...
# Processing batch 227/2108...
# Processing batch 228/2108...
# Processing batch 229/2108...
# Processing batch 230/2108...
# Processing batch 231/2108...
# Processing batch 232/2108...
# Processing batch 233/2108...
# Processing batch 234/2108...
# Processing batch 235/2108...
# Processing batch 236/2108...
# Processing batch 237/2108...
# Processing batch 238/2108...
# Processing batch 239/2108...
# Processing batch 240/2108...
# Processing batch 241/2108...
# Processing batch 242/2108...
# Processing batch 243/2108...
# Processing batch 244/2108...
# Processing batch 245/2108...
# Processing batch 246/2108...
# Processing batch 247/2108...
# Processing batch 248/2108...
# Processing batch 249/2108...
# Processing batch 250/2108...
# Processing batch 251/2108...
# Processing batch 252/2108...
# Processing batch 253/2108...
# Processing batch 254/2108...
# Processing batch 255/2108...
# Processing batch 256/2108...
# Processing batch 257/2108...
# Processing batch 258/2108...
# Processing batch 259/2108...
# Processing batch 260/2108...
# Processing batch 261/2108...
# Processing batch 262/2108...
# Processing batch 263/2108...
# Processing batch 264/2108...
# Processing batch 265/2108...
# Processing batch 266/2108...
# Processing batch 267/2108...
# Processing batch 268/2108...
# Processing batch 269/2108...
# Processing batch 270/2108...
# Processing batch 271/2108...
# Processing batch 272/2108...
# Processing batch 273/2108...
# Processing batch 274/2108...
# Processing batch 275/2108...
# Processing batch 276/2108...
# Processing batch 277/2108...
# Processing batch 278/2108...
# Processing batch 279/2108...
# Processing batch 280/2108...
# Processing batch 281/2108...
# Processing batch 282/2108...
# Processing batch 283/2108...
# Processing batch 284/2108...
# Processing batch 285/2108...
# Processing batch 286/2108...
# Processing batch 287/2108...
# Processing batch 288/2108...
# Processing batch 289/2108...
# Processing batch 290/2108...
# Processing batch 291/2108...
# Processing batch 292/2108...
# Processing batch 293/2108...
# Processing batch 294/2108...
# Processing batch 295/2108...
# Processing batch 296/2108...
# Processing batch 297/2108...
# Processing batch 298/2108...
# Processing batch 299/2108...
# Processing batch 300/2108...
# Processing batch 301/2108...
# Processing batch 302/2108...
# Processing batch 303/2108...
# Processing batch 304/2108...
# Processing batch 305/2108...
# Processing batch 306/2108...
# Processing batch 307/2108...
# Processing batch 308/2108...
# Processing batch 309/2108...
# Processing batch 310/2108...
# Processing batch 311/2108...
# Processing batch 312/2108...
# Processing batch 313/2108...
# Processing batch 314/2108...
# Processing batch 315/2108...
# Processing batch 316/2108...
# Processing batch 317/2108...
# Processing batch 318/2108...
# Processing batch 319/2108...
# Processing batch 320/2108...
# Processing batch 321/2108...
# Processing batch 322/2108...
# Processing batch 323/2108...
# Processing batch 324/2108...
# Processing batch 325/2108...
# Processing batch 326/2108...
# Processing batch 327/2108...
# Processing batch 328/2108...
# Processing batch 329/2108...
# Processing batch 330/2108...
# Processing batch 331/2108...
# Processing batch 332/2108...
# Processing batch 333/2108...
# Processing batch 334/2108...
# Processing batch 335/2108...
# Processing batch 336/2108...
# Processing batch 337/2108...
# Processing batch 338/2108...
# Processing batch 339/2108...
# Processing batch 340/2108...
# Processing batch 341/2108...
# Processing batch 342/2108...
# Processing batch 343/2108...
# Processing batch 344/2108...
# Processing batch 345/2108...
# Processing batch 346/2108...
# Processing batch 347/2108...
# Processing batch 348/2108...
# Processing batch 349/2108...
# Processing batch 350/2108...
# Processing batch 351/2108...
# Processing batch 352/2108...
# Processing batch 353/2108...
# Processing batch 354/2108...
# Processing batch 355/2108...
# Processing batch 356/2108...
# Processing batch 357/2108...
# Processing batch 358/2108...
# Processing batch 359/2108...
# Processing batch 360/2108...
# Processing batch 361/2108...
# Processing batch 362/2108...
# Processing batch 363/2108...
# Processing batch 364/2108...
# Processing batch 365/2108...
# Processing batch 366/2108...
# Processing batch 367/2108...
# Processing batch 368/2108...
# Processing batch 369/2108...
# Processing batch 370/2108...
# Processing batch 371/2108...
# Processing batch 372/2108...
# Processing batch 373/2108...
# Processing batch 374/2108...
# Processing batch 375/2108...
# Processing batch 376/2108...
# Processing batch 377/2108...
# Processing batch 378/2108...
# Processing batch 379/2108...
# Processing batch 380/2108...
# Processing batch 381/2108...
# Processing batch 382/2108...
# Processing batch 383/2108...
# Processing batch 384/2108...
# Processing batch 385/2108...
# Processing batch 386/2108...
# Processing batch 387/2108...
# Processing batch 388/2108...
# Processing batch 389/2108...
# Processing batch 390/2108...
# Processing batch 391/2108...
# Processing batch 392/2108...
# Processing batch 393/2108...
# Processing batch 394/2108...
# Processing batch 395/2108...
# Processing batch 396/2108...
# Processing batch 397/2108...
# Processing batch 398/2108...
# Processing batch 399/2108...
# Processing batch 400/2108...
# Processing batch 401/2108...
# Processing batch 402/2108...
# Processing batch 403/2108...
# Processing batch 404/2108...
# Processing batch 405/2108...
# Processing batch 406/2108...
# Processing batch 407/2108...
# Processing batch 408/2108...
# Processing batch 409/2108...
# Processing batch 410/2108...
# Processing batch 411/2108...
# Processing batch 412/2108...
# Processing batch 413/2108...
# Processing batch 414/2108...
# Processing batch 415/2108...
# Processing batch 416/2108...
# Processing batch 417/2108...
# Processing batch 418/2108...
# Processing batch 419/2108...
# Processing batch 420/2108...
# Processing batch 421/2108...
# Processing batch 422/2108...
# Processing batch 423/2108...
# Processing batch 424/2108...
# Processing batch 425/2108...
# Processing batch 426/2108...
# Processing batch 427/2108...
# Processing batch 428/2108...
# Processing batch 429/2108...
# Processing batch 430/2108...
# Processing batch 431/2108...
# Processing batch 432/2108...
# Processing batch 433/2108...
# Processing batch 434/2108...
# Processing batch 435/2108...
# Processing batch 436/2108...
# Processing batch 437/2108...
# Processing batch 438/2108...
# Processing batch 439/2108...
# Processing batch 440/2108...
# Processing batch 441/2108...
# Processing batch 442/2108...
# Processing batch 443/2108...
# Processing batch 444/2108...
# Processing batch 445/2108...
# Processing batch 446/2108...
# Processing batch 447/2108...
# Processing batch 448/2108...
# Processing batch 449/2108...
# Processing batch 450/2108...
# Processing batch 451/2108...
# Processing batch 452/2108...
# Processing batch 453/2108...
# Processing batch 454/2108...
# Processing batch 455/2108...
# Processing batch 456/2108...
# Processing batch 457/2108...
# Processing batch 458/2108...
# Processing batch 459/2108...
# Processing batch 460/2108...
# Processing batch 461/2108...
# Processing batch 462/2108...
# Processing batch 463/2108...
# Processing batch 464/2108...
# Processing batch 465/2108...
# Processing batch 466/2108...
# Processing batch 467/2108...
# Processing batch 468/2108...
# Processing batch 469/2108...
# Processing batch 470/2108...
# Processing batch 471/2108...
# Processing batch 472/2108...
# Processing batch 473/2108...
# Processing batch 474/2108...
# Processing batch 475/2108...
# Processing batch 476/2108...
# Processing batch 477/2108...
# Processing batch 478/2108...
# Processing batch 479/2108...
# Processing batch 480/2108...
# Processing batch 481/2108...
# Processing batch 482/2108...
# Processing batch 483/2108...
# Processing batch 484/2108...
# Processing batch 485/2108...
# Processing batch 486/2108...
# Processing batch 487/2108...
# Processing batch 488/2108...
# Processing batch 489/2108...
# Processing batch 490/2108...
# Processing batch 491/2108...
# Processing batch 492/2108...
# Processing batch 493/2108...
# Processing batch 494/2108...
# Processing batch 495/2108...
# Processing batch 496/2108...
# Processing batch 497/2108...
# Processing batch 498/2108...
# Processing batch 499/2108...
# Processing batch 500/2108...
# Processing batch 501/2108...
# Processing batch 502/2108...
# Processing batch 503/2108...
# Processing batch 504/2108...
# Processing batch 505/2108...
# Processing batch 506/2108...
# Processing batch 507/2108...
# Processing batch 508/2108...
# Processing batch 509/2108...
# Processing batch 510/2108...
# Processing batch 511/2108...
# Processing batch 512/2108...
# Processing batch 513/2108...
# Processing batch 514/2108...
# Processing batch 515/2108...
# Processing batch 516/2108...
# Processing batch 517/2108...
# Processing batch 518/2108...
# Processing batch 519/2108...
# Processing batch 520/2108...
# Processing batch 521/2108...
# Processing batch 522/2108...
# Processing batch 523/2108...
# Processing batch 524/2108...
# Processing batch 525/2108...
# Processing batch 526/2108...
# Processing batch 527/2108...
# Processing batch 528/2108...
# Processing batch 529/2108...
# Processing batch 530/2108...
# Processing batch 531/2108...
# Processing batch 532/2108...
# Processing batch 533/2108...
# Processing batch 534/2108...
# Processing batch 535/2108...
# Processing batch 536/2108...
# Processing batch 537/2108...
# Processing batch 538/2108...
# Processing batch 539/2108...
# Processing batch 540/2108...
# Processing batch 541/2108...
# Processing batch 542/2108...
# Processing batch 543/2108...
# Processing batch 544/2108...
# Processing batch 545/2108...
# Processing batch 546/2108...
# Processing batch 547/2108...
# Processing batch 548/2108...
# Processing batch 549/2108...
# Processing batch 550/2108...
# Processing batch 551/2108...
# Processing batch 552/2108...
# Processing batch 553/2108...
# Processing batch 554/2108...
# Processing batch 555/2108...
# Processing batch 556/2108...
# Processing batch 557/2108...
# Processing batch 558/2108...
# Processing batch 559/2108...
# Processing batch 560/2108...
# Processing batch 561/2108...
# Processing batch 562/2108...
# Processing batch 563/2108...
# Processing batch 564/2108...
# Processing batch 565/2108...
# Processing batch 566/2108...
# Processing batch 567/2108...
# Processing batch 568/2108...
# Processing batch 569/2108...
# Processing batch 570/2108...
# Processing batch 571/2108...
# Processing batch 572/2108...
# Processing batch 573/2108...
# Processing batch 574/2108...
# Processing batch 575/2108...
# Processing batch 576/2108...
# Processing batch 577/2108...
# Processing batch 578/2108...
# Processing batch 579/2108...
# Processing batch 580/2108...
# Processing batch 581/2108...
# Processing batch 582/2108...
# Processing batch 583/2108...
# Processing batch 584/2108...
# Processing batch 585/2108...
# Processing batch 586/2108...
# Processing batch 587/2108...
# Processing batch 588/2108...
# Processing batch 589/2108...
# Processing batch 590/2108...
# Processing batch 591/2108...
# Processing batch 592/2108...
# Processing batch 593/2108...
# Processing batch 594/2108...
# Processing batch 595/2108...
# Processing batch 596/2108...
# Processing batch 597/2108...
# Processing batch 598/2108...
# Processing batch 599/2108...
# Processing batch 600/2108...
# Processing batch 601/2108...
# Processing batch 602/2108...
# Processing batch 603/2108...
# Processing batch 604/2108...
# Processing batch 605/2108...
# Processing batch 606/2108...
# Processing batch 607/2108...
# Processing batch 608/2108...
# Processing batch 609/2108...
# Processing batch 610/2108...
# Processing batch 611/2108...
# Processing batch 612/2108...
# Processing batch 613/2108...
# Processing batch 614/2108...
# Processing batch 615/2108...
# Processing batch 616/2108...
# Processing batch 617/2108...
# Processing batch 618/2108...
# Processing batch 619/2108...
# Processing batch 620/2108...
# Processing batch 621/2108...
# Processing batch 622/2108...
# Processing batch 623/2108...
# Processing batch 624/2108...
# Processing batch 625/2108...
# Processing batch 626/2108...
# Processing batch 627/2108...
# Processing batch 628/2108...
# Processing batch 629/2108...
# Processing batch 630/2108...
# Processing batch 631/2108...
# Processing batch 632/2108...
# Processing batch 633/2108...
# Processing batch 634/2108...
# Processing batch 635/2108...
# Processing batch 636/2108...
# Processing batch 637/2108...
# Processing batch 638/2108...
# Processing batch 639/2108...
# Processing batch 640/2108...
# Processing batch 641/2108...
# Processing batch 642/2108...
# Processing batch 643/2108...
# Processing batch 644/2108...
# Processing batch 645/2108...
# Processing batch 646/2108...
# Processing batch 647/2108...
# Processing batch 648/2108...
# Processing batch 649/2108...
# Processing batch 650/2108...
# Processing batch 651/2108...
# Processing batch 652/2108...
# Processing batch 653/2108...
# Processing batch 654/2108...
# Processing batch 655/2108...
# Processing batch 656/2108...
# Processing batch 657/2108...
# Processing batch 658/2108...
# Processing batch 659/2108...
# Processing batch 660/2108...
# Processing batch 661/2108...
# Processing batch 662/2108...
# Processing batch 663/2108...
# Processing batch 664/2108...
# Processing batch 665/2108...
# Processing batch 666/2108...
# Processing batch 667/2108...
# Processing batch 668/2108...
# Processing batch 669/2108...
# Processing batch 670/2108...
# Processing batch 671/2108...
# Processing batch 672/2108...
# Processing batch 673/2108...
# Processing batch 674/2108...
# Processing batch 675/2108...
# Processing batch 676/2108...
# Processing batch 677/2108...
# Processing batch 678/2108...
# Processing batch 679/2108...
# Processing batch 680/2108...
# Processing batch 681/2108...
# Processing batch 682/2108...
# Processing batch 683/2108...
# Processing batch 684/2108...
# Processing batch 685/2108...
# Processing batch 686/2108...
# Processing batch 687/2108...
# Processing batch 688/2108...
# Processing batch 689/2108...
# Processing batch 690/2108...
# Processing batch 691/2108...
# Processing batch 692/2108...
# Processing batch 693/2108...
# Processing batch 694/2108...
# Processing batch 695/2108...
# Processing batch 696/2108...
# Processing batch 697/2108...
# Processing batch 698/2108...
# Processing batch 699/2108...
# Processing batch 700/2108...
# Processing batch 701/2108...
# Processing batch 702/2108...
# Processing batch 703/2108...
# Processing batch 704/2108...
# Processing batch 705/2108...
# Processing batch 706/2108...
# Processing batch 707/2108...
# Processing batch 708/2108...
# Processing batch 709/2108...
# Processing batch 710/2108...
# Processing batch 711/2108...
# Processing batch 712/2108...
# Processing batch 713/2108...
# Processing batch 714/2108...
# Processing batch 715/2108...
# Processing batch 716/2108...
# Processing batch 717/2108...
# Processing batch 718/2108...
# Processing batch 719/2108...
# Processing batch 720/2108...
# Processing batch 721/2108...
# Processing batch 722/2108...
# Processing batch 723/2108...
# Processing batch 724/2108...
# Processing batch 725/2108...
# Processing batch 726/2108...
# Processing batch 727/2108...
# Processing batch 728/2108...
# Processing batch 729/2108...
# Processing batch 730/2108...
# Processing batch 731/2108...
# Processing batch 732/2108...
# Processing batch 733/2108...
# Processing batch 734/2108...
# Processing batch 735/2108...
# Processing batch 736/2108...
# Processing batch 737/2108...
# Processing batch 738/2108...
# Processing batch 739/2108...
# Processing batch 740/2108...
# Processing batch 741/2108...
# Processing batch 742/2108...
# Processing batch 743/2108...
# Processing batch 744/2108...
# Processing batch 745/2108...
# Processing batch 746/2108...
# Processing batch 747/2108...
# Processing batch 748/2108...
# Processing batch 749/2108...
# Processing batch 750/2108...
# Processing batch 751/2108...
# Processing batch 752/2108...
# Processing batch 753/2108...
# Processing batch 754/2108...
# Processing batch 755/2108...
# Processing batch 756/2108...
# Processing batch 757/2108...
# Processing batch 758/2108...
# Processing batch 759/2108...
# Processing batch 760/2108...
# Processing batch 761/2108...
# Processing batch 762/2108...
# Processing batch 763/2108...
# Processing batch 764/2108...
# Processing batch 765/2108...
# Processing batch 766/2108...
# Processing batch 767/2108...
# Processing batch 768/2108...
# Processing batch 769/2108...
# Processing batch 770/2108...
# Processing batch 771/2108...
# Processing batch 772/2108...
# Processing batch 773/2108...
# Processing batch 774/2108...
# Processing batch 775/2108...
# Processing batch 776/2108...
# Processing batch 777/2108...
# Processing batch 778/2108...
# Processing batch 779/2108...
# Processing batch 780/2108...
# Processing batch 781/2108...
# Processing batch 782/2108...
# Processing batch 783/2108...
# Processing batch 784/2108...
# Processing batch 785/2108...
# Processing batch 786/2108...
# Processing batch 787/2108...
# Processing batch 788/2108...
# Processing batch 789/2108...
# Processing batch 790/2108...
# Processing batch 791/2108...
# Processing batch 792/2108...
# Processing batch 793/2108...
# Processing batch 794/2108...
# Processing batch 795/2108...
# Processing batch 796/2108...
# Processing batch 797/2108...
# Processing batch 798/2108...
# Processing batch 799/2108...
# Processing batch 800/2108...
# Processing batch 801/2108...
# Processing batch 802/2108...
# Processing batch 803/2108...
# Processing batch 804/2108...
# Processing batch 805/2108...
# Processing batch 806/2108...
# Processing batch 807/2108...
# Processing batch 808/2108...
# Processing batch 809/2108...
# Processing batch 810/2108...
# Processing batch 811/2108...
# Processing batch 812/2108...
# Processing batch 813/2108...
# Processing batch 814/2108...
# Processing batch 815/2108...
# Processing batch 816/2108...
# Processing batch 817/2108...
# Processing batch 818/2108...
# Processing batch 819/2108...
# Processing batch 820/2108...
# Processing batch 821/2108...
# Processing batch 822/2108...
# Processing batch 823/2108...
# Processing batch 824/2108...
# Processing batch 825/2108...
# Processing batch 826/2108...
# Processing batch 827/2108...
# Processing batch 828/2108...
# Processing batch 829/2108...
# Processing batch 830/2108...
# Processing batch 831/2108...
# Processing batch 832/2108...
# Processing batch 833/2108...
# Processing batch 834/2108...
# Processing batch 835/2108...
# Processing batch 836/2108...
# Processing batch 837/2108...
# Processing batch 838/2108...
# Processing batch 839/2108...
# Processing batch 840/2108...
# Processing batch 841/2108...
# Processing batch 842/2108...
# Processing batch 843/2108...
# Processing batch 844/2108...
# Processing batch 845/2108...
# Processing batch 846/2108...
# Processing batch 847/2108...
# Processing batch 848/2108...
# Processing batch 849/2108...
# Processing batch 850/2108...
# Processing batch 851/2108...
# Processing batch 852/2108...
# Processing batch 853/2108...
# Processing batch 854/2108...
# Processing batch 855/2108...
# Processing batch 856/2108...
# Processing batch 857/2108...
# Processing batch 858/2108...
# Processing batch 859/2108...
# Processing batch 860/2108...
# Processing batch 861/2108...
# Processing batch 862/2108...
# Processing batch 863/2108...
# Processing batch 864/2108...
# Processing batch 865/2108...
# Processing batch 866/2108...
# Processing batch 867/2108...
# Processing batch 868/2108...
# Processing batch 869/2108...
# Processing batch 870/2108...
# Processing batch 871/2108...
# Processing batch 872/2108...
# Processing batch 873/2108...
# Processing batch 874/2108...
# Processing batch 875/2108...
# Processing batch 876/2108...
# Processing batch 877/2108...
# Processing batch 878/2108...
# Processing batch 879/2108...
# Processing batch 880/2108...
# Processing batch 881/2108...
# Processing batch 882/2108...
# Processing batch 883/2108...
# Processing batch 884/2108...
# Processing batch 885/2108...
# Processing batch 886/2108...
# Processing batch 887/2108...
# Processing batch 888/2108...
# Processing batch 889/2108...
# Processing batch 890/2108...
# Processing batch 891/2108...
# Processing batch 892/2108...
# Processing batch 893/2108...
# Processing batch 894/2108...
# Processing batch 895/2108...
# Processing batch 896/2108...
# Processing batch 897/2108...
# Processing batch 898/2108...
# Processing batch 899/2108...
# Processing batch 900/2108...
# Processing batch 901/2108...
# Processing batch 902/2108...
# Processing batch 903/2108...
# Processing batch 904/2108...
# Processing batch 905/2108...
# Processing batch 906/2108...
# Processing batch 907/2108...
# Processing batch 908/2108...
# Processing batch 909/2108...
# Processing batch 910/2108...
# Processing batch 911/2108...
# Processing batch 912/2108...
# Processing batch 913/2108...
# Processing batch 914/2108...
# Processing batch 915/2108...
# Processing batch 916/2108...
# Processing batch 917/2108...
# Processing batch 918/2108...
# Processing batch 919/2108...
# Processing batch 920/2108...
# Processing batch 921/2108...
# Processing batch 922/2108...
# Processing batch 923/2108...
# Processing batch 924/2108...
# Processing batch 925/2108...
# Processing batch 926/2108...
# Processing batch 927/2108...
# Processing batch 928/2108...
# Processing batch 929/2108...
# Processing batch 930/2108...
# Processing batch 931/2108...
# Processing batch 932/2108...
# Processing batch 933/2108...
# Processing batch 934/2108...
# Processing batch 935/2108...
# Processing batch 936/2108...
# Processing batch 937/2108...
# Processing batch 938/2108...
# Processing batch 939/2108...
# Processing batch 940/2108...
# Processing batch 941/2108...
# Processing batch 942/2108...
# Processing batch 943/2108...
# Processing batch 944/2108...
# Processing batch 945/2108...
# Processing batch 946/2108...
# Processing batch 947/2108...
# Processing batch 948/2108...
# Processing batch 949/2108...
# Processing batch 950/2108...
# Processing batch 951/2108...
# Processing batch 952/2108...
# Processing batch 953/2108...
# Processing batch 954/2108...
# Processing batch 955/2108...
# Processing batch 956/2108...
# Processing batch 957/2108...
# Processing batch 958/2108...
# Processing batch 959/2108...
# Processing batch 960/2108...
# Processing batch 961/2108...
# Processing batch 962/2108...
# Processing batch 963/2108...
# Processing batch 964/2108...
# Processing batch 965/2108...
# Processing batch 966/2108...
# Processing batch 967/2108...
# Processing batch 968/2108...
# Processing batch 969/2108...
# Processing batch 970/2108...
# Processing batch 971/2108...
# Processing batch 972/2108...
# Processing batch 973/2108...
# Processing batch 974/2108...
# Processing batch 975/2108...
# Processing batch 976/2108...
# Processing batch 977/2108...
# Processing batch 978/2108...
# Processing batch 979/2108...
# Processing batch 980/2108...
# Processing batch 981/2108...
# Processing batch 982/2108...
# Processing batch 983/2108...
# Processing batch 984/2108...
# Processing batch 985/2108...
# Processing batch 986/2108...
# Processing batch 987/2108...
# Processing batch 988/2108...
# Processing batch 989/2108...
# Processing batch 990/2108...
# Processing batch 991/2108...
# Processing batch 992/2108...
# Processing batch 993/2108...
# Processing batch 994/2108...
# Processing batch 995/2108...
# Processing batch 996/2108...
# Processing batch 997/2108...
# Processing batch 998/2108...
# Processing batch 999/2108...
# Processing batch 1000/2108...
# Processing batch 1001/2108...
# Processing batch 1002/2108...
# Processing batch 1003/2108...
# Processing batch 1004/2108...
# Processing batch 1005/2108...
# Processing batch 1006/2108...
# Processing batch 1007/2108...
# Processing batch 1008/2108...
# Processing batch 1009/2108...
# Processing batch 1010/2108...
# Processing batch 1011/2108...
# Processing batch 1012/2108...
# Processing batch 1013/2108...
# Processing batch 1014/2108...
# Processing batch 1015/2108...
# Processing batch 1016/2108...
# Processing batch 1017/2108...
# Processing batch 1018/2108...
# Processing batch 1019/2108...
# Processing batch 1020/2108...
# Processing batch 1021/2108...
# Processing batch 1022/2108...
# Processing batch 1023/2108...
# Processing batch 1024/2108...
# Processing batch 1025/2108...
# Processing batch 1026/2108...
# Processing batch 1027/2108...
# Processing batch 1028/2108...
# Processing batch 1029/2108...
# Processing batch 1030/2108...
# Processing batch 1031/2108...
# Processing batch 1032/2108...
# Processing batch 1033/2108...
# Processing batch 1034/2108...
# Processing batch 1035/2108...
# Processing batch 1036/2108...
# Processing batch 1037/2108...
# Processing batch 1038/2108...
# Processing batch 1039/2108...
# Processing batch 1040/2108...
# Processing batch 1041/2108...
# Processing batch 1042/2108...
# Processing batch 1043/2108...
# Processing batch 1044/2108...
# Processing batch 1045/2108...
# Processing batch 1046/2108...
# Processing batch 1047/2108...
# Processing batch 1048/2108...
# Processing batch 1049/2108...
# Processing batch 1050/2108...
# Processing batch 1051/2108...
# Processing batch 1052/2108...
# Processing batch 1053/2108...
# Processing batch 1054/2108...
# Processing batch 1055/2108...
# Processing batch 1056/2108...
# Processing batch 1057/2108...
# Processing batch 1058/2108...
# Processing batch 1059/2108...
# Processing batch 1060/2108...
# Processing batch 1061/2108...
# Processing batch 1062/2108...
# Processing batch 1063/2108...
# Processing batch 1064/2108...
# Processing batch 1065/2108...
# Processing batch 1066/2108...
# Processing batch 1067/2108...
# Processing batch 1068/2108...
# Processing batch 1069/2108...
# Processing batch 1070/2108...
# Processing batch 1071/2108...
# Processing batch 1072/2108...
# Processing batch 1073/2108...
# Processing batch 1074/2108...
# Processing batch 1075/2108...
# Processing batch 1076/2108...
# Processing batch 1077/2108...
# Processing batch 1078/2108...
# Processing batch 1079/2108...
# Processing batch 1080/2108...
# Processing batch 1081/2108...
# Processing batch 1082/2108...
# Processing batch 1083/2108...
# Processing batch 1084/2108...
# Processing batch 1085/2108...
# Processing batch 1086/2108...
# Processing batch 1087/2108...
# Processing batch 1088/2108...
# Processing batch 1089/2108...
# Processing batch 1090/2108...
# Processing batch 1091/2108...
# Processing batch 1092/2108...
# Processing batch 1093/2108...
# Processing batch 1094/2108...
# Processing batch 1095/2108...
# Processing batch 1096/2108...
# Processing batch 1097/2108...
# Processing batch 1098/2108...
# Processing batch 1099/2108...
# Processing batch 1100/2108...
# Processing batch 1101/2108...
# Processing batch 1102/2108...
# Processing batch 1103/2108...
# Processing batch 1104/2108...
# Processing batch 1105/2108...
# Processing batch 1106/2108...
# Processing batch 1107/2108...
# Processing batch 1108/2108...
# Processing batch 1109/2108...
# Processing batch 1110/2108...
# Processing batch 1111/2108...
# Processing batch 1112/2108...
# Processing batch 1113/2108...
# Processing batch 1114/2108...
# Processing batch 1115/2108...
# Processing batch 1116/2108...
# Processing batch 1117/2108...
# Processing batch 1118/2108...
# Processing batch 1119/2108...
# Processing batch 1120/2108...
# Processing batch 1121/2108...
# Processing batch 1122/2108...
# Processing batch 1123/2108...
# Processing batch 1124/2108...
# Processing batch 1125/2108...
# Processing batch 1126/2108...
# Processing batch 1127/2108...
# Processing batch 1128/2108...
# Processing batch 1129/2108...
# Processing batch 1130/2108...
# Processing batch 1131/2108...
# Processing batch 1132/2108...
# Processing batch 1133/2108...
# Processing batch 1134/2108...
# Processing batch 1135/2108...
# Processing batch 1136/2108...
# Processing batch 1137/2108...
# Processing batch 1138/2108...
# Processing batch 1139/2108...
# Processing batch 1140/2108...
# Processing batch 1141/2108...
# Processing batch 1142/2108...
# Processing batch 1143/2108...
# Processing batch 1144/2108...
# Processing batch 1145/2108...
# Processing batch 1146/2108...
# Processing batch 1147/2108...
# Processing batch 1148/2108...
# Processing batch 1149/2108...
# Processing batch 1150/2108...
# Processing batch 1151/2108...
# Processing batch 1152/2108...
# Processing batch 1153/2108...
# Processing batch 1154/2108...
# Processing batch 1155/2108...
# Processing batch 1156/2108...
# Processing batch 1157/2108...
# Processing batch 1158/2108...
# Processing batch 1159/2108...
# Processing batch 1160/2108...
# Processing batch 1161/2108...
# Processing batch 1162/2108...
# Processing batch 1163/2108...
# Processing batch 1164/2108...
# Processing batch 1165/2108...
# Processing batch 1166/2108...
# Processing batch 1167/2108...
# Processing batch 1168/2108...
# Processing batch 1169/2108...
# Processing batch 1170/2108...
# Processing batch 1171/2108...
# Processing batch 1172/2108...
# Processing batch 1173/2108...
# Processing batch 1174/2108...
# Processing batch 1175/2108...
# Processing batch 1176/2108...
# Processing batch 1177/2108...
# Processing batch 1178/2108...
# Processing batch 1179/2108...
# Processing batch 1180/2108...
# Processing batch 1181/2108...
# Processing batch 1182/2108...
# Processing batch 1183/2108...
# Processing batch 1184/2108...
# Processing batch 1185/2108...
# Processing batch 1186/2108...
# Processing batch 1187/2108...
# Processing batch 1188/2108...
# Processing batch 1189/2108...
# Processing batch 1190/2108...
# Processing batch 1191/2108...
# Processing batch 1192/2108...
# Processing batch 1193/2108...
# Processing batch 1194/2108...
# Processing batch 1195/2108...
# Processing batch 1196/2108...
# Processing batch 1197/2108...
# Processing batch 1198/2108...
# Processing batch 1199/2108...
# Processing batch 1200/2108...
# Processing batch 1201/2108...
# Processing batch 1202/2108...
# Processing batch 1203/2108...
# Processing batch 1204/2108...
# Processing batch 1205/2108...
# Processing batch 1206/2108...
# Processing batch 1207/2108...
# Processing batch 1208/2108...
# Processing batch 1209/2108...
# Processing batch 1210/2108...
# Processing batch 1211/2108...
# Processing batch 1212/2108...
# Processing batch 1213/2108...
# Processing batch 1214/2108...
# Processing batch 1215/2108...
# Processing batch 1216/2108...
# Processing batch 1217/2108...
# Processing batch 1218/2108...
# Processing batch 1219/2108...
# Processing batch 1220/2108...
# Processing batch 1221/2108...
# Processing batch 1222/2108...
# Processing batch 1223/2108...
# Processing batch 1224/2108...
# Processing batch 1225/2108...
# Processing batch 1226/2108...
# Processing batch 1227/2108...
# Processing batch 1228/2108...
# Processing batch 1229/2108...
# Processing batch 1230/2108...
# Processing batch 1231/2108...
# Processing batch 1232/2108...
# Processing batch 1233/2108...
# Processing batch 1234/2108...
# Processing batch 1235/2108...
# Processing batch 1236/2108...
# Processing batch 1237/2108...
# Processing batch 1238/2108...
# Processing batch 1239/2108...
# Processing batch 1240/2108...
# Processing batch 1241/2108...
# Processing batch 1242/2108...
# Processing batch 1243/2108...
# Processing batch 1244/2108...
# Processing batch 1245/2108...
# Processing batch 1246/2108...
# Processing batch 1247/2108...
# Processing batch 1248/2108...
# Processing batch 1249/2108...
# Processing batch 1250/2108...
# Processing batch 1251/2108...
# Processing batch 1252/2108...
# Processing batch 1253/2108...
# Processing batch 1254/2108...
# Processing batch 1255/2108...
# Processing batch 1256/2108...
# Processing batch 1257/2108...
# Processing batch 1258/2108...
# Processing batch 1259/2108...
# Processing batch 1260/2108...
# Processing batch 1261/2108...
# Processing batch 1262/2108...
# Processing batch 1263/2108...
# Processing batch 1264/2108...
# Processing batch 1265/2108...
# Processing batch 1266/2108...
# Processing batch 1267/2108...
# Processing batch 1268/2108...
# Processing batch 1269/2108...
# Processing batch 1270/2108...
# Processing batch 1271/2108...
# Processing batch 1272/2108...
# Processing batch 1273/2108...
# Processing batch 1274/2108...
# Processing batch 1275/2108...
# Processing batch 1276/2108...
# Processing batch 1277/2108...
# Processing batch 1278/2108...
# Processing batch 1279/2108...
# Processing batch 1280/2108...
# Processing batch 1281/2108...
# Processing batch 1282/2108...
# Processing batch 1283/2108...
# Processing batch 1284/2108...
# Processing batch 1285/2108...
# Processing batch 1286/2108...
# Processing batch 1287/2108...
# Processing batch 1288/2108...
# Processing batch 1289/2108...
# Processing batch 1290/2108...
# Processing batch 1291/2108...
# Processing batch 1292/2108...
# Processing batch 1293/2108...
# Processing batch 1294/2108...
# Processing batch 1295/2108...
# Processing batch 1296/2108...
# Processing batch 1297/2108...
# Processing batch 1298/2108...
# Processing batch 1299/2108...
# Processing batch 1300/2108...
# Processing batch 1301/2108...
# Processing batch 1302/2108...
# Processing batch 1303/2108...
# Processing batch 1304/2108...
# Processing batch 1305/2108...
# Processing batch 1306/2108...
# Processing batch 1307/2108...
# Processing batch 1308/2108...
# Processing batch 1309/2108...
# Processing batch 1310/2108...
# Processing batch 1311/2108...
# Processing batch 1312/2108...
# Processing batch 1313/2108...
# Processing batch 1314/2108...
# Processing batch 1315/2108...
# Processing batch 1316/2108...
# Processing batch 1317/2108...
# Processing batch 1318/2108...
# Processing batch 1319/2108...
# Processing batch 1320/2108...
# Processing batch 1321/2108...
# Processing batch 1322/2108...
# Processing batch 1323/2108...
# Processing batch 1324/2108...
# Processing batch 1325/2108...
# Processing batch 1326/2108...
# Processing batch 1327/2108...
# Processing batch 1328/2108...
# Processing batch 1329/2108...
# Processing batch 1330/2108...
# Processing batch 1331/2108...
# Processing batch 1332/2108...
# Processing batch 1333/2108...
# Processing batch 1334/2108...
# Processing batch 1335/2108...
# Processing batch 1336/2108...
# Processing batch 1337/2108...
# Processing batch 1338/2108...
# Processing batch 1339/2108...
# Processing batch 1340/2108...
# Processing batch 1341/2108...
# Processing batch 1342/2108...
# Processing batch 1343/2108...
# Processing batch 1344/2108...
# Processing batch 1345/2108...
# Processing batch 1346/2108...
# Processing batch 1347/2108...
# Processing batch 1348/2108...
# Processing batch 1349/2108...
# Processing batch 1350/2108...
# Processing batch 1351/2108...
# Processing batch 1352/2108...
# Processing batch 1353/2108...
# Processing batch 1354/2108...
# Processing batch 1355/2108...
# Processing batch 1356/2108...
# Processing batch 1357/2108...
# Processing batch 1358/2108...
# Processing batch 1359/2108...
# Processing batch 1360/2108...
# Processing batch 1361/2108...
# Processing batch 1362/2108...
# Processing batch 1363/2108...
# Processing batch 1364/2108...
# Processing batch 1365/2108...
# Processing batch 1366/2108...
# Processing batch 1367/2108...
# Processing batch 1368/2108...
# Processing batch 1369/2108...
# Processing batch 1370/2108...
# Processing batch 1371/2108...
# Processing batch 1372/2108...
# Processing batch 1373/2108...
# Processing batch 1374/2108...
# Processing batch 1375/2108...
# Processing batch 1376/2108...
# Processing batch 1377/2108...
# Processing batch 1378/2108...
# Processing batch 1379/2108...
# Processing batch 1380/2108...
# Processing batch 1381/2108...
# Processing batch 1382/2108...
# Processing batch 1383/2108...
# Processing batch 1384/2108...
# Processing batch 1385/2108...
# Processing batch 1386/2108...
# Processing batch 1387/2108...
# Processing batch 1388/2108...
# Processing batch 1389/2108...
# Processing batch 1390/2108...
# Processing batch 1391/2108...
# Processing batch 1392/2108...
# Processing batch 1393/2108...
# Processing batch 1394/2108...
# Processing batch 1395/2108...
# Processing batch 1396/2108...
# Processing batch 1397/2108...
# Processing batch 1398/2108...
# Processing batch 1399/2108...
# Processing batch 1400/2108...
# Processing batch 1401/2108...
# Processing batch 1402/2108...
# Processing batch 1403/2108...
# Processing batch 1404/2108...
# Processing batch 1405/2108...
# Processing batch 1406/2108...
# Processing batch 1407/2108...
# Processing batch 1408/2108...
# Processing batch 1409/2108...
# Processing batch 1410/2108...
# Processing batch 1411/2108...
# Processing batch 1412/2108...
# Processing batch 1413/2108...
# Processing batch 1414/2108...
# Processing batch 1415/2108...
# Processing batch 1416/2108...
# Processing batch 1417/2108...
# Processing batch 1418/2108...
# Processing batch 1419/2108...
# Processing batch 1420/2108...
# Processing batch 1421/2108...
# Processing batch 1422/2108...
# Processing batch 1423/2108...
# Processing batch 1424/2108...
# Processing batch 1425/2108...
# Processing batch 1426/2108...
# Processing batch 1427/2108...
# Processing batch 1428/2108...
# Processing batch 1429/2108...
# Processing batch 1430/2108...
# Processing batch 1431/2108...
# Processing batch 1432/2108...
# Processing batch 1433/2108...
# Processing batch 1434/2108...
# Processing batch 1435/2108...
# Processing batch 1436/2108...
# Processing batch 1437/2108...
# Processing batch 1438/2108...
# Processing batch 1439/2108...
# Processing batch 1440/2108...
# Processing batch 1441/2108...
# Processing batch 1442/2108...
# Processing batch 1443/2108...
# Processing batch 1444/2108...
# Processing batch 1445/2108...
# Processing batch 1446/2108...
# Processing batch 1447/2108...
# Processing batch 1448/2108...
# Processing batch 1449/2108...
# Processing batch 1450/2108...
# Processing batch 1451/2108...
# Processing batch 1452/2108...
# Processing batch 1453/2108...
# Processing batch 1454/2108...
# Processing batch 1455/2108...
# Processing batch 1456/2108...
# Processing batch 1457/2108...
# Processing batch 1458/2108...
# Processing batch 1459/2108...
# Processing batch 1460/2108...
# Processing batch 1461/2108...
# Processing batch 1462/2108...
# Processing batch 1463/2108...
# Processing batch 1464/2108...
# Processing batch 1465/2108...
# Processing batch 1466/2108...
# Processing batch 1467/2108...
# Processing batch 1468/2108...
# Processing batch 1469/2108...
# Processing batch 1470/2108...
# Processing batch 1471/2108...
# Processing batch 1472/2108...
# Processing batch 1473/2108...
# Processing batch 1474/2108...
# Processing batch 1475/2108...
# Processing batch 1476/2108...
# Processing batch 1477/2108...
# Processing batch 1478/2108...
# Processing batch 1479/2108...
# Processing batch 1480/2108...
# Processing batch 1481/2108...
# Processing batch 1482/2108...
# Processing batch 1483/2108...
# Processing batch 1484/2108...
# Processing batch 1485/2108...
# Processing batch 1486/2108...
# Processing batch 1487/2108...
# Processing batch 1488/2108...
# Processing batch 1489/2108...
# Processing batch 1490/2108...
# Processing batch 1491/2108...
# Processing batch 1492/2108...
# Processing batch 1493/2108...
# Processing batch 1494/2108...
# Processing batch 1495/2108...
# Processing batch 1496/2108...
# Processing batch 1497/2108...
# Processing batch 1498/2108...
# Processing batch 1499/2108...
# Processing batch 1500/2108...
# Processing batch 1501/2108...
# Processing batch 1502/2108...
# Processing batch 1503/2108...
# Processing batch 1504/2108...
# Processing batch 1505/2108...
# Processing batch 1506/2108...
# Processing batch 1507/2108...
# Processing batch 1508/2108...
# Processing batch 1509/2108...
# Processing batch 1510/2108...
# Processing batch 1511/2108...
# Processing batch 1512/2108...
# Processing batch 1513/2108...
# Processing batch 1514/2108...
# Processing batch 1515/2108...
# Processing batch 1516/2108...
# Processing batch 1517/2108...
# Processing batch 1518/2108...
# Processing batch 1519/2108...
# Processing batch 1520/2108...
# Processing batch 1521/2108...
# Processing batch 1522/2108...
# Processing batch 1523/2108...
# Processing batch 1524/2108...
# Processing batch 1525/2108...
# Processing batch 1526/2108...
# Processing batch 1527/2108...
# Processing batch 1528/2108...
# Processing batch 1529/2108...
# Processing batch 1530/2108...
# Processing batch 1531/2108...
# Processing batch 1532/2108...
# Processing batch 1533/2108...
# Processing batch 1534/2108...
# Processing batch 1535/2108...
# Processing batch 1536/2108...
# Processing batch 1537/2108...
# Processing batch 1538/2108...
# Processing batch 1539/2108...
# Processing batch 1540/2108...
# Processing batch 1541/2108...
# Processing batch 1542/2108...
# Processing batch 1543/2108...
# Processing batch 1544/2108...
# Processing batch 1545/2108...
# Processing batch 1546/2108...
# Processing batch 1547/2108...
# Processing batch 1548/2108...
# Processing batch 1549/2108...
# Processing batch 1550/2108...
# Processing batch 1551/2108...
# Processing batch 1552/2108...
# Processing batch 1553/2108...
# Processing batch 1554/2108...
# Processing batch 1555/2108...
# Processing batch 1556/2108...
# Processing batch 1557/2108...
# Processing batch 1558/2108...
# Processing batch 1559/2108...
# Processing batch 1560/2108...
# Processing batch 1561/2108...
# Processing batch 1562/2108...
# Processing batch 1563/2108...
# Processing batch 1564/2108...
# Processing batch 1565/2108...
# Processing batch 1566/2108...
# Processing batch 1567/2108...
# Processing batch 1568/2108...
# Processing batch 1569/2108...
# Processing batch 1570/2108...
# Processing batch 1571/2108...
# Processing batch 1572/2108...
# Processing batch 1573/2108...
# Processing batch 1574/2108...
# Processing batch 1575/2108...
# Processing batch 1576/2108...
# Processing batch 1577/2108...
# Processing batch 1578/2108...
# Processing batch 1579/2108...
# Processing batch 1580/2108...
# Processing batch 1581/2108...
# Processing batch 1582/2108...
# Processing batch 1583/2108...
# Processing batch 1584/2108...
# Processing batch 1585/2108...
# Processing batch 1586/2108...
# Processing batch 1587/2108...
# Processing batch 1588/2108...
# Processing batch 1589/2108...
# Processing batch 1590/2108...
# Processing batch 1591/2108...
# Processing batch 1592/2108...
# Processing batch 1593/2108...
# Processing batch 1594/2108...
# Processing batch 1595/2108...
# Processing batch 1596/2108...
# Processing batch 1597/2108...
# Processing batch 1598/2108...
# Processing batch 1599/2108...
# Processing batch 1600/2108...
# Processing batch 1601/2108...
# Processing batch 1602/2108...
# Processing batch 1603/2108...
# Processing batch 1604/2108...
# Processing batch 1605/2108...
# Processing batch 1606/2108...
# Processing batch 1607/2108...
# Processing batch 1608/2108...
# Processing batch 1609/2108...
# Processing batch 1610/2108...
# Processing batch 1611/2108...
# Processing batch 1612/2108...
# Processing batch 1613/2108...
# Processing batch 1614/2108...
# Processing batch 1615/2108...
# Processing batch 1616/2108...
# Processing batch 1617/2108...
# Processing batch 1618/2108...
# Processing batch 1619/2108...
# Processing batch 1620/2108...
# Processing batch 1621/2108...
# Processing batch 1622/2108...
# Processing batch 1623/2108...
# Processing batch 1624/2108...
# Processing batch 1625/2108...
# Processing batch 1626/2108...
# Processing batch 1627/2108...
# Processing batch 1628/2108...
# Processing batch 1629/2108...
# Processing batch 1630/2108...
# Processing batch 1631/2108...
# Processing batch 1632/2108...
# Processing batch 1633/2108...
# Processing batch 1634/2108...
# Processing batch 1635/2108...
# Processing batch 1636/2108...
# Processing batch 1637/2108...
# Processing batch 1638/2108...
# Processing batch 1639/2108...
# Processing batch 1640/2108...
# Processing batch 1641/2108...
# Processing batch 1642/2108...
# Processing batch 1643/2108...
# Processing batch 1644/2108...
# Processing batch 1645/2108...
# Processing batch 1646/2108...
# Processing batch 1647/2108...
# Processing batch 1648/2108...
# Processing batch 1649/2108...
# Processing batch 1650/2108...
# Processing batch 1651/2108...
# Processing batch 1652/2108...
# Processing batch 1653/2108...
# Processing batch 1654/2108...
# Processing batch 1655/2108...
# Processing batch 1656/2108...
# Processing batch 1657/2108...
# Processing batch 1658/2108...
# Processing batch 1659/2108...
# Processing batch 1660/2108...
# Processing batch 1661/2108...
# Processing batch 1662/2108...
# Processing batch 1663/2108...
# Processing batch 1664/2108...
# Processing batch 1665/2108...
# Processing batch 1666/2108...
# Processing batch 1667/2108...
# Processing batch 1668/2108...
# Processing batch 1669/2108...
# Processing batch 1670/2108...
# Processing batch 1671/2108...
# Processing batch 1672/2108...
# Processing batch 1673/2108...
# Processing batch 1674/2108...
# Processing batch 1675/2108...
# Processing batch 1676/2108...
# Processing batch 1677/2108...
# Processing batch 1678/2108...
# Processing batch 1679/2108...
# Processing batch 1680/2108...
# Processing batch 1681/2108...
# Processing batch 1682/2108...
# Processing batch 1683/2108...
# Processing batch 1684/2108...
# Processing batch 1685/2108...
# Processing batch 1686/2108...
# Processing batch 1687/2108...
# Processing batch 1688/2108...
# Processing batch 1689/2108...
# Processing batch 1690/2108...
# Processing batch 1691/2108...
# Processing batch 1692/2108...
# Processing batch 1693/2108...
# Processing batch 1694/2108...
# Processing batch 1695/2108...
# Processing batch 1696/2108...
# Processing batch 1697/2108...
# Processing batch 1698/2108...
# Processing batch 1699/2108...
# Processing batch 1700/2108...
# Processing batch 1701/2108...
# Processing batch 1702/2108...
# Processing batch 1703/2108...
# Processing batch 1704/2108...
# Processing batch 1705/2108...
# Processing batch 1706/2108...
# Processing batch 1707/2108...
# Processing batch 1708/2108...
# Processing batch 1709/2108...
# Processing batch 1710/2108...
# Processing batch 1711/2108...
# Processing batch 1712/2108...
# Processing batch 1713/2108...
# Processing batch 1714/2108...
# Processing batch 1715/2108...
# Processing batch 1716/2108...
# Processing batch 1717/2108...
# Processing batch 1718/2108...
# Processing batch 1719/2108...
# Processing batch 1720/2108...
# Processing batch 1721/2108...
# Processing batch 1722/2108...
# Processing batch 1723/2108...
# Processing batch 1724/2108...
# Processing batch 1725/2108...
# Processing batch 1726/2108...
# Processing batch 1727/2108...
# Processing batch 1728/2108...
# Processing batch 1729/2108...
# Processing batch 1730/2108...
# Processing batch 1731/2108...
# Processing batch 1732/2108...
# Processing batch 1733/2108...
# Processing batch 1734/2108...
# Processing batch 1735/2108...
# Processing batch 1736/2108...
# Processing batch 1737/2108...
# Processing batch 1738/2108...
# Processing batch 1739/2108...
# Processing batch 1740/2108...
# Processing batch 1741/2108...
# Processing batch 1742/2108...
# Processing batch 1743/2108...
# Processing batch 1744/2108...
# Processing batch 1745/2108...
# Processing batch 1746/2108...
# Processing batch 1747/2108...
# Processing batch 1748/2108...
# Processing batch 1749/2108...
# Processing batch 1750/2108...
# Processing batch 1751/2108...
# Processing batch 1752/2108...
# Processing batch 1753/2108...
# Processing batch 1754/2108...
# Processing batch 1755/2108...
# Processing batch 1756/2108...
# Processing batch 1757/2108...
# Processing batch 1758/2108...
# Processing batch 1759/2108...
# Processing batch 1760/2108...
# Processing batch 1761/2108...
# Processing batch 1762/2108...
# Processing batch 1763/2108...
# Processing batch 1764/2108...
# Processing batch 1765/2108...
# Processing batch 1766/2108...
# Processing batch 1767/2108...
# Processing batch 1768/2108...
# Processing batch 1769/2108...
# Processing batch 1770/2108...
# Processing batch 1771/2108...
# Processing batch 1772/2108...
# Processing batch 1773/2108...
# Processing batch 1774/2108...
# Processing batch 1775/2108...
# Processing batch 1776/2108...
# Processing batch 1777/2108...
# Processing batch 1778/2108...
# Processing batch 1779/2108...
# Processing batch 1780/2108...
# Processing batch 1781/2108...
# Processing batch 1782/2108...
# Processing batch 1783/2108...
# Processing batch 1784/2108...
# Processing batch 1785/2108...
# Processing batch 1786/2108...
# Processing batch 1787/2108...
# Processing batch 1788/2108...
# Processing batch 1789/2108...
# Processing batch 1790/2108...
# Processing batch 1791/2108...
# Processing batch 1792/2108...
# Processing batch 1793/2108...
# Processing batch 1794/2108...
# Processing batch 1795/2108...
# Processing batch 1796/2108...
# Processing batch 1797/2108...
# Processing batch 1798/2108...
# Processing batch 1799/2108...
# Processing batch 1800/2108...
# Processing batch 1801/2108...
# Processing batch 1802/2108...
# Processing batch 1803/2108...
# Processing batch 1804/2108...
# Processing batch 1805/2108...
# Processing batch 1806/2108...
# Processing batch 1807/2108...
# Processing batch 1808/2108...
# Processing batch 1809/2108...
# Processing batch 1810/2108...
# Processing batch 1811/2108...
# Processing batch 1812/2108...
# Processing batch 1813/2108...
# Processing batch 1814/2108...
# Processing batch 1815/2108...
# Processing batch 1816/2108...
# Processing batch 1817/2108...
# Processing batch 1818/2108...
# Processing batch 1819/2108...
# Processing batch 1820/2108...
# Processing batch 1821/2108...
# Processing batch 1822/2108...
# Processing batch 1823/2108...
# Processing batch 1824/2108...
# Processing batch 1825/2108...
# Processing batch 1826/2108...
# Processing batch 1827/2108...
# Processing batch 1828/2108...
# Processing batch 1829/2108...
# Processing batch 1830/2108...
# Processing batch 1831/2108...
# Processing batch 1832/2108...
# Processing batch 1833/2108...
# Processing batch 1834/2108...
# Processing batch 1835/2108...
# Processing batch 1836/2108...
# Processing batch 1837/2108...
# Processing batch 1838/2108...
# Processing batch 1839/2108...
# Processing batch 1840/2108...
# Processing batch 1841/2108...
# Processing batch 1842/2108...
# Processing batch 1843/2108...
# Processing batch 1844/2108...
# Processing batch 1845/2108...
# Processing batch 1846/2108...
# Processing batch 1847/2108...
# Processing batch 1848/2108...
# Processing batch 1849/2108...
# Processing batch 1850/2108...
# Processing batch 1851/2108...
# Processing batch 1852/2108...
# Processing batch 1853/2108...
# Processing batch 1854/2108...
# Processing batch 1855/2108...
# Processing batch 1856/2108...
# Processing batch 1857/2108...
# Processing batch 1858/2108...
# Processing batch 1859/2108...
# Processing batch 1860/2108...
# Processing batch 1861/2108...
# Processing batch 1862/2108...
# Processing batch 1863/2108...
# Processing batch 1864/2108...
# Processing batch 1865/2108...
# Processing batch 1866/2108...
# Processing batch 1867/2108...
# Processing batch 1868/2108...
# Processing batch 1869/2108...
# Processing batch 1870/2108...
# Processing batch 1871/2108...
# Processing batch 1872/2108...
# Processing batch 1873/2108...
# Processing batch 1874/2108...
# Processing batch 1875/2108...
# Processing batch 1876/2108...
# Processing batch 1877/2108...
# Processing batch 1878/2108...
# Processing batch 1879/2108...
# Processing batch 1880/2108...
# Processing batch 1881/2108...
# Processing batch 1882/2108...
# Processing batch 1883/2108...
# Processing batch 1884/2108...
# Processing batch 1885/2108...
# Processing batch 1886/2108...
# Processing batch 1887/2108...
# Processing batch 1888/2108...
# Processing batch 1889/2108...
# Processing batch 1890/2108...
# Processing batch 1891/2108...
# Processing batch 1892/2108...
# Processing batch 1893/2108...
# Processing batch 1894/2108...
# Processing batch 1895/2108...
# Processing batch 1896/2108...
# Processing batch 1897/2108...
# Processing batch 1898/2108...
# Processing batch 1899/2108...
# Processing batch 1900/2108...
# Processing batch 1901/2108...
# Processing batch 1902/2108...
# Processing batch 1903/2108...
# Processing batch 1904/2108...
# Processing batch 1905/2108...
# Processing batch 1906/2108...
# Processing batch 1907/2108...
# Processing batch 1908/2108...
# Processing batch 1909/2108...
# Processing batch 1910/2108...
# Processing batch 1911/2108...
# Processing batch 1912/2108...
# Processing batch 1913/2108...
# Processing batch 1914/2108...
# Processing batch 1915/2108...
# Processing batch 1916/2108...
# Processing batch 1917/2108...
# Processing batch 1918/2108...
# Processing batch 1919/2108...
# Processing batch 1920/2108...
# Processing batch 1921/2108...
# Processing batch 1922/2108...
# Processing batch 1923/2108...
# Processing batch 1924/2108...
# Processing batch 1925/2108...
# Processing batch 1926/2108...
# Processing batch 1927/2108...
# Processing batch 1928/2108...
# Processing batch 1929/2108...
# Processing batch 1930/2108...
# Processing batch 1931/2108...
# Processing batch 1932/2108...
# Processing batch 1933/2108...
# Processing batch 1934/2108...
# Processing batch 1935/2108...
# Processing batch 1936/2108...
# Processing batch 1937/2108...
# Processing batch 1938/2108...
# Processing batch 1939/2108...
# Processing batch 1940/2108...
# Processing batch 1941/2108...
# Processing batch 1942/2108...
# Processing batch 1943/2108...
# Processing batch 1944/2108...
# Processing batch 1945/2108...
# Processing batch 1946/2108...
# Processing batch 1947/2108...
# Processing batch 1948/2108...
# Processing batch 1949/2108...
# Processing batch 1950/2108...
# Processing batch 1951/2108...
# Processing batch 1952/2108...
# Processing batch 1953/2108...
# Processing batch 1954/2108...
# Processing batch 1955/2108...
# Processing batch 1956/2108...
# Processing batch 1957/2108...
# Processing batch 1958/2108...
# Processing batch 1959/2108...
# Processing batch 1960/2108...
# Processing batch 1961/2108...
# Processing batch 1962/2108...
# Processing batch 1963/2108...
# Processing batch 1964/2108...
# Processing batch 1965/2108...
# Processing batch 1966/2108...
# Processing batch 1967/2108...
# Processing batch 1968/2108...
# Processing batch 1969/2108...
# Processing batch 1970/2108...
# Processing batch 1971/2108...
# Processing batch 1972/2108...
# Processing batch 1973/2108...
# Processing batch 1974/2108...
# Processing batch 1975/2108...
# Processing batch 1976/2108...
# Processing batch 1977/2108...
# Processing batch 1978/2108...
# Processing batch 1979/2108...
# Processing batch 1980/2108...
# Processing batch 1981/2108...
# Processing batch 1982/2108...
# Processing batch 1983/2108...
# Processing batch 1984/2108...
# Processing batch 1985/2108...
# Processing batch 1986/2108...
# Processing batch 1987/2108...
# Processing batch 1988/2108...
# Processing batch 1989/2108...
# Processing batch 1990/2108...
# Processing batch 1991/2108...
# Processing batch 1992/2108...
# Processing batch 1993/2108...
# Processing batch 1994/2108...
# Processing batch 1995/2108...
# Processing batch 1996/2108...
# Processing batch 1997/2108...
# Processing batch 1998/2108...
# Processing batch 1999/2108...
# Processing batch 2000/2108...
# Processing batch 2001/2108...
# Processing batch 2002/2108...
# Processing batch 2003/2108...
# Processing batch 2004/2108...
# Processing batch 2005/2108...
# Processing batch 2006/2108...
# Processing batch 2007/2108...
# Processing batch 2008/2108...
# Processing batch 2009/2108...
# Processing batch 2010/2108...
# Processing batch 2011/2108...
# Processing batch 2012/2108...
# Processing batch 2013/2108...
# Processing batch 2014/2108...
# Processing batch 2015/2108...
# Processing batch 2016/2108...
# Processing batch 2017/2108...
# Processing batch 2018/2108...
# Processing batch 2019/2108...
# Processing batch 2020/2108...
# Processing batch 2021/2108...
# Processing batch 2022/2108...
# Processing batch 2023/2108...
# Processing batch 2024/2108...
# Processing batch 2025/2108...
# Processing batch 2026/2108...
# Processing batch 2027/2108...
# Processing batch 2028/2108...
# Processing batch 2029/2108...
# Processing batch 2030/2108...
# Processing batch 2031/2108...
# Processing batch 2032/2108...
# Processing batch 2033/2108...
# Processing batch 2034/2108...
# Processing batch 2035/2108...
# Processing batch 2036/2108...
# Processing batch 2037/2108...
# Processing batch 2038/2108...
# Processing batch 2039/2108...
# Processing batch 2040/2108...
# Processing batch 2041/2108...
# Processing batch 2042/2108...
# Processing batch 2043/2108...
# Processing batch 2044/2108...
# Processing batch 2045/2108...
# Processing batch 2046/2108...
# Processing batch 2047/2108...
# Processing batch 2048/2108...
# Processing batch 2049/2108...
# Processing batch 2050/2108...
# Processing batch 2051/2108...
# Processing batch 2052/2108...
# Processing batch 2053/2108...
# Processing batch 2054/2108...
# Processing batch 2055/2108...
# Processing batch 2056/2108...
# Processing batch 2057/2108...
# Processing batch 2058/2108...
# Processing batch 2059/2108...
# Processing batch 2060/2108...
# Processing batch 2061/2108...
# Processing batch 2062/2108...
# Processing batch 2063/2108...
# Processing batch 2064/2108...
# Processing batch 2065/2108...
# Processing batch 2066/2108...
# Processing batch 2067/2108...
# Processing batch 2068/2108...
# Processing batch 2069/2108...
# Processing batch 2070/2108...
# Processing batch 2071/2108...
# Processing batch 2072/2108...
# Processing batch 2073/2108...
# Processing batch 2074/2108...
# Processing batch 2075/2108...
# Processing batch 2076/2108...
# Processing batch 2077/2108...
# Processing batch 2078/2108...
# Processing batch 2079/2108...
# Processing batch 2080/2108...
# Processing batch 2081/2108...
# Processing batch 2082/2108...
# Processing batch 2083/2108...
# Processing batch 2084/2108...
# Processing batch 2085/2108...
# Processing batch 2086/2108...
# Processing batch 2087/2108...
# Processing batch 2088/2108...
# Processing batch 2089/2108...
# Processing batch 2090/2108...
# Processing batch 2091/2108...
# Processing batch 2092/2108...
# Processing batch 2093/2108...
# Processing batch 2094/2108...
# Processing batch 2095/2108...
# Processing batch 2096/2108...
# Processing batch 2097/2108...
# Processing batch 2098/2108...
# Processing batch 2099/2108...
# Processing batch 2100/2108...
# Processing batch 2101/2108...
# Processing batch 2102/2108...
# Processing batch 2103/2108...
# Processing batch 2104/2108...
# Processing batch 2105/2108...
# Processing batch 2106/2108...
# Processing batch 2107/2108...
# Processing batch 2108/2108...

# %%
model.save_pretrained("./fine_tuned_model")
tokenizer.save_pretrained("./fine_tuned_model")
# Out:
# ('./fine_tuned_model/tokenizer_config.json',
#  './fine_tuned_model/special_tokens_map.json',
#  './fine_tuned_model/spiece.model',
#  './fine_tuned_model/added_tokens.json')

# %%
# !pip install streamlit transformers
# Out:
# Collecting streamlit
#   Downloading streamlit-1.41.0-py2.py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.44.2)
# Requirement already satisfied: altair<6,>=4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (4.2.2)
# Requirement already satisfied: blinker<2,>=1.0.0 in /usr/lib/python3/dist-packages (from streamlit) (1.4)
# Requirement already satisfied: cachetools<6,>=4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (5.5.0)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (8.1.7)
# Requirement already satisfied: numpy<3,>=1.23 in /usr/local/lib/python3.10/dist-packages (from streamlit) (1.26.4)
# Requirement already satisfied: packaging<25,>=20 in /usr/local/lib/python3.10/dist-packages (from streamlit) (24.1)
# Requirement already satisfied: pandas<3,>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (2.1.4)
# Requirement already satisfied: pillow<12,>=7.1.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (10.4.0)
# Requirement already satisfied: protobuf<6,>=3.20 in /usr/local/lib/python3.10/dist-packages (from streamlit) (3.20.3)
# Requirement already satisfied: pyarrow>=7.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (18.1.0)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.10/dist-packages (from streamlit) (2.32.3)
# Requirement already satisfied: rich<14,>=10.14.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (13.8.1)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (9.0.0)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.10/dist-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (4.12.2)
# Collecting watchdog<7,>=2.1.5 (from streamlit)
#   Downloading watchdog-6.0.0-py3-none-manylinux2014_x86_64.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 2.4 MB/s eta 0:00:00
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit)
#   Downloading GitPython-3.1.43-py3-none-any.whl.metadata (13 kB)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tornado<7,>=6.0.3 in /usr/local/lib/python3.10/dist-packages (from streamlit) (6.3.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.24.7)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.9.11)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.5)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (0.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (0.12.1)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading gitdb-4.0.11-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.6.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.4.0->streamlit) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.4.0->streamlit) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.4.0->streamlit) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (2024.8.30)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich<14,>=10.14.0->streamlit) (2.18.0)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading smmap-5.0.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.5)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.16.0)
# Downloading streamlit-1.41.0-py2.py3-none-any.whl (23.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.4/23.4 MB 64.9 MB/s eta 0:00:00
# Downloading GitPython-3.1.43-py3-none-any.whl (207 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 34.2 MB/s eta 0:00:00
# Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 60.9 MB/s eta 0:00:00
# Downloading watchdog-6.0.0-py3-none-manylinux2014_x86_64.whl (79 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 13.6 MB/s eta 0:00:00
# Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 10.9 MB/s eta 0:00:00
# Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Installing collected packages: watchdog, smmap, pydeck, gitdb, gitpython, streamlit
# Successfully installed gitdb-4.0.11 gitpython-3.1.43 pydeck-0.9.1 smmap-5.0.1 streamlit-1.41.0 watchdog-6.0.0

# %%
# %%writefile app.py
import streamlit as st
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, pipeline

# Load the fine-tuned QA model and tokenizer
model_path = "./fine_tuned_model"  # Replace with your model directory
tokenizer = AutoTokenizer.from_pretrained(model_path)
model = AutoModelForSeq2SeqLM.from_pretrained(model_path)

# Initialize the QA pipeline
qa_pipeline = pipeline("text2text-generation", model=model, tokenizer=tokenizer)

# Streamlit app
st.title("Biomedical QA Model")
st.write("Enter a question about biomedical entities, and the model will answer based on its knowledge.")

# User input
question = st.text_input("Ask a question:")

# Generate the answer
if question:
    response = qa_pipeline(question, max_length=512, num_return_sequences=1)
    answer = response[0]["generated_text"]

    # Display the answer
    st.write("Answer:", answer)
# Out:
# Writing app.py

# %%
# !streamlit run app.py &>/content/logs.txt &

# %%
# !npm install -g localtunnel
# !npx localtunnel --port 8501
# Out:
# added 22 packages, and audited 23 packages in 2s
#
# 3 packages are looking for funding
#   run `npm fund` for details
#
# 1 moderate severity vulnerability
#
# To address all issues (including breaking changes), run:
#   npm audit fix --force
#
# Run `npm audit` for details.
# npm notice
# npm notice New major version of npm available! 8.19.4 -> 10.9.2
# npm notice Changelog: https://github.com/npm/cli/releases/tag/v10.9.2
# npm notice Run npm install -g npm@10.9.2 to update!
# npm notice
# your url is: https://blue-boxes-march.loca.lt
# ^C

# %% [markdown]
# Metrics to evaluate

# %%
def exact_match(predictions, true_answers):
    matches = [1 if pred.strip() == true.strip() else 0 for pred, true in zip(predictions, true_answers)]
    return sum(matches) / len(matches) * 100

# Compute EM
em_score = exact_match(predicted_answers, true_answers)
print(f"Exact Match Score: {em_score:.2f}%")
# Out:
# Exact Match Score: 29.61%

# %%
from sklearn.metrics import f1_score
from collections import Counter

def compute_f1(predictions, true_answers):
    def get_tokens(text):
        return Counter(text.split())

    f1_scores = []
    for pred, true in zip(predictions, true_answers):
        pred_tokens = get_tokens(pred)
        true_tokens = get_tokens(true)
        common = pred_tokens & true_tokens
        num_same = sum(common.values())

        if num_same == 0:
            f1_scores.append(0)
        else:
            precision = num_same / sum(pred_tokens.values())
            recall = num_same / sum(true_tokens.values())
            f1_scores.append(2 * precision * recall / (precision + recall))

    return sum(f1_scores) / len(f1_scores) * 100

# Compute F1
f1_score = compute_f1(predicted_answers, true_answers)
print(f"F1 Score: {f1_score:.2f}")
# Out:
# F1 Score: 52.57

# %%
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction

def compute_bleu(predictions, true_answers):
    smoothing_fn = SmoothingFunction().method4  # Smooth for short sentences
    bleu_scores = [sentence_bleu([true.split()], pred.split(), smoothing_function=smoothing_fn) for pred, true in zip(predictions, true_answers)]
    return sum(bleu_scores) / len(bleu_scores) * 100

# Compute BLEU
bleu_score = compute_bleu(predicted_answers, true_answers)
print(f"BLEU Score: {bleu_score:.2f}")
# Out:
# BLEU Score: 40.70

# %%
pip install rouge
# Out:
# Requirement already satisfied: rouge in /usr/local/lib/python3.10/dist-packages (1.0.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from rouge) (1.16.0)

# %%
from rouge import Rouge

def compute_rouge(predictions, true_answers):
    rouge = Rouge()
    scores = rouge.get_scores(predictions, true_answers, avg=True)
    return scores

# Compute ROUGE
rouge_scores = compute_rouge(predicted_answers, true_answers)
print(f"ROUGE Scores: {rouge_scores}")
# Out:
# ROUGE Scores: {'rouge-1': {'r': 0.5175842381847008, 'p': 0.5991390809865483, 'f': 0.5417793390207815}, 'rouge-2': {'r': 0.43484453710122956, 'p': 0.49677263944790756, 'f': 0.4537840860773102}, 'rouge-l': {'r': 0.5109337250976455, 'p': 0.5902916130668928, 'f': 0.5345991962416808}}
